# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\vivek\\Downloads\\economic_indicators_dataset_2010_2023.csv")

# %%
df
# Out:
#            Date    Country  Inflation Rate (%)  GDP Growth Rate (%)  \
# 0    2010-01-31     Brazil                1.23                 0.69
# 1    2010-01-31     France                6.76                 2.59
# 2    2010-01-31        USA                7.46                 4.84
# 3    2010-02-28     Brazil                5.43                 0.31
# 4    2010-02-28     Canada                0.69                -0.52
# ..          ...        ...                 ...                  ...
# 495  2023-08-31      Japan                5.71                -3.85
# 496  2023-08-31         UK                4.82                 8.95
# 497  2023-09-30        USA                7.32                 0.61
# 498  2023-10-31    Germany                8.04                -2.23
# 499  2023-11-30  Australia                9.23                 6.16
#
#      Unemployment Rate (%)  Interest Rate (%)  Stock Index Value
# 0                    10.48               7.71           21748.85
# ...

# %%
df.head()
# Out:
#          Date Country  Inflation Rate (%)  GDP Growth Rate (%)  \
# 0  2010-01-31  Brazil                1.23                 0.69
# 1  2010-01-31  France                6.76                 2.59
# 2  2010-01-31     USA                7.46                 4.84
# 3  2010-02-28  Brazil                5.43                 0.31
# 4  2010-02-28  Canada                0.69                -0.52
#
#    Unemployment Rate (%)  Interest Rate (%)  Stock Index Value
# 0                  10.48               7.71           21748.85
# 1                   4.27               7.39           10039.56
# 2                   2.64               6.39           13129.10
# 3                   8.26               6.09           23304.58
# 4                  11.92              -0.51           16413.03

# %%
df.tail()
# Out:
#            Date    Country  Inflation Rate (%)  GDP Growth Rate (%)  \
# 495  2023-08-31      Japan                5.71                -3.85
# 496  2023-08-31         UK                4.82                 8.95
# 497  2023-09-30        USA                7.32                 0.61
# 498  2023-10-31    Germany                8.04                -2.23
# 499  2023-11-30  Australia                9.23                 6.16
#
#      Unemployment Rate (%)  Interest Rate (%)  Stock Index Value
# 495                   4.69               8.50            5968.07
# 496                  10.91               8.87           21731.52
# 497                   9.36               4.58           38924.38
# 498                   2.89               8.04           39107.07
# 499                   6.78               9.49           21072.66

# %%
df.isnull().sum()
# Out:
# Date                     0
# Country                  0
# Inflation Rate (%)       0
# GDP Growth Rate (%)      0
# Unemployment Rate (%)    0
# Interest Rate (%)        0
# Stock Index Value        0
# dtype: int64

# %%
import matplotlib as plt

# %%
plt.plot(df['Unemployment Rate (%)'],df['GDP Growth Rate (%)'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 plt.plot(df['Unemployment Rate (%)'],df['GDP Growth Rate (%)'])
#
# File C:\Python313\Lib\site-packages\matplotlib\_api\__init__.py:218, in caching_module_getattr.<locals>.__getattr__(name)
#     216 if name in props:
#     217     return props[name].__get__(instance)
# --> 218 raise AttributeError(
#     219     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'plot'

# %% [markdown]
# ## Top 5 Countries with the Highest Average Unemployment Rate

# %%
df.groupby('Country')['Unemployment Rate (%)'].mean().sort_values(ascending=False).head()
# Out:
# Country
# UK           7.711739
# USA          7.309123
# Australia    7.121176
# Japan        7.036296
# Canada       6.927021
# Name: Unemployment Rate (%), dtype: float64

# %% [markdown]
# ## Top 5 Countries with the Lowest Average Unemployment Rate

# %%
df.groupby('Country')['Employment Rate (%)'].mean().sort_values(ascending=False).head()
# Out:
# Country
# Germany    93.822195
# China      93.667073
# India      93.384821
# Brazil     93.180208
# France     93.177119
# Name: Employment Rate (%), dtype: float64

# %% [markdown]
# ## Countries with the Highest Average GDP Growth Rate

# %%
df.groupby('Country')['GDP Growth Rate (%)'].mean().sort_values(ascending=False).head()
# Out:
# Country
# Japan        3.443889
# UK           3.191522
# Brazil       2.972500
# Australia    2.736078
# China        2.708537
# Name: GDP Growth Rate (%), dtype: float64

# %% [markdown]
# ## Countries with the Lowest Average GDP Growth Rate

# %%
df.groupby('Country')['GDP Growth Rate (%)'].mean().sort_values(ascending=True).head()
# Out:
# Country
# Canada     1.179787
# USA        1.726667
# France     2.016610
# Germany    2.023902
# India      2.241250
# Name: GDP Growth Rate (%), dtype: float64

# %% [markdown]
# ## Countries with the Highest Peak Stock Index Value

# %%
df.groupby('Country')['Stock Index Value'].max().sort_values(ascending=False).head()
# Out:
# Country
# France    39982.21
# UK        39854.23
# Brazil    39705.25
# India     39613.37
# Japan     39518.72
# Name: Stock Index Value, dtype: float64

# %% [markdown]
# ## Global Trend of Unemployment and Inflation Over Time

# %%
df.groupby('Date')[['Unemployment Rate (%)', 'Inflation Rate (%)']].mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.head()
# Out:
#          Date Country  Inflation Rate (%)  GDP Growth Rate (%)  \
# 0  2010-01-31  Brazil                1.23                 0.69
# 1  2010-01-31  France                6.76                 2.59
# 2  2010-01-31     USA                7.46                 4.84
# 3  2010-02-28  Brazil                5.43                 0.31
# 4  2010-02-28  Canada                0.69                -0.52
#
#    Unemployment Rate (%)  Interest Rate (%)  Stock Index Value  \
# 0                  10.48               7.71           21748.85
# 1                   4.27               7.39           10039.56
# 2                   2.64               6.39           13129.10
# 3                   8.26               6.09           23304.58
# 4                  11.92              -0.51           16413.03
#
#    Employment Rate (%)
# 0                89.52
# 1                95.73
# 2                97.36
# 3                91.74
# 4                88.08

# %% [markdown]
# ##  Average employment Rate by Country

# %%
df.groupby('Country')['Employment Rate (%)'].mean().plot()
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# ## 🔍 Summary of Key Insights
#
# - The **United Kingdom** has the highest average unemployment rate, followed by the **United States**.
# - **Germany** and  **China** have the lowest average unemployment rates, showing strong employment stability.
# - **Japan** leads in average GDP growth, followed by 🇬🇧 the **United Kingdom**.
# - **Canada** and the **United States** have the lowest average GDP growth rates, indicating slow economic expansion.
# - **France** recorded the **highest peak stock index value**, followed by the **United Kingdom**, reflecting strong market performance.

# %% [markdown]
# > 📌 **Notice:**
# > Please note that the dataset used in this analysis is **randomly generated** and does not reflect real-world economic data. The insights, rankings, and trends observed (such as unemployment rates, GDP growth, and stock index values) are purely for **educational and analytical ** purposes.
# > These results should not be interpreted as actual economic indicators or used for policy, financial, or research decisions.
